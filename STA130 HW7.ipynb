# %%
# Q4

import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url) 
pokeaman
import statsmodels.formula.api as smf

model1_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") + C(Generation) + Q("Sp. Def"):C(Generation)', data=pokeaman)
model2_spec = smf.ols(formula='HP ~ Q("Sp. Def") * C(Generation)', data=pokeaman)

model2_fit = model2_spec.fit()
model2_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     HP   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     15.27
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           3.50e-27
# Time:                        00:26:33   Log-Likelihood:                -3649.4
# No. Observations:                 800   AIC:                             7323.
# Df Residuals:                     788   BIC:                             7379.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Q4:
# For example, in a simple linear regression y = mx + b, the data may in fact have a quadratic relationship such as y = mx^2 +b, that is increasing upward. But, since we are trying to do a linear fit on the data, it clearly doesn't explain the variability in the data, in the sense that when x is large and increases, y increases much more than linear model predicts due to the quadratic. However, the overall trend of the quadratic data points are still upwards, meaning the line of best fit we draw, would definitely be upward with the slope being positive. This fitted slope would have p value much smaller than 0.05, since there is indeed an upward trend, so there is definitely an effect of increasing x causing y to increase, which gives the statistical significance.
#
# So, in this multi-dimensional fit, while we find that there are 5 independent variables that have values larger than 10, with p values much smaller than 0.05, this only says the general trend is upward: as these 5 independent variables increase, it is "beyond reasonable doubt" that the value y would increase, this is what p value less than 0.05 means. However, the actual data y may depend on these 5 independent variables in much more complicated ways than simple linear. Hence, this gives a small R^2.
#
#
# ChatGPT Summary:
# Yes, exactly. You've captured the distinction perfectly.
#
# In this multi-dimensional regression, finding that 5 independent variables have large coefficients and p-values below 0.05 tells us that there is indeed a strong statistical association between these variables and
# 𝑦
# y. Specifically:
#
# Significance (p-values < 0.05): The low p-values indicate that there is strong evidence against the null hypothesis of "no effect," meaning these variables likely have a genuine impact on
# 𝑦
# y. In simpler terms, as these independent variables increase, there’s a high probability (beyond reasonable doubt) that
# 𝑦
# y also increases, regardless of the specific nature of the relationship.
#
# However:
#
# Complex Relationship (Low R-squared): The low R-squared value suggests that the relationship between these independent variables and
# 𝑦
# y is likely more complex than what a linear model can capture. This could mean that
# 𝑦
# y might depend on these variables in non-linear, interactive, or higher-order ways that the linear model is not accounting for. Hence, while each variable shows an upward trend with
# 𝑦
# y individually, the model’s overall fit is weak because it doesn’t accurately capture the entire variability in
# 𝑦
# y.
# This scenario reflects a limitation of linear models in multi-dimensional spaces: they can indicate directional trends and significance but may fail to fully explain the complexity of
# 𝑦
# y’s dependency on the predictors, resulting in a low R-squared value.
#
#
# ChatGPT Link:
# https://chatgpt.com/share/67369958-c008-800a-b705-4b2829e3bdae
